# %% [markdown]
# # <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Heart Disease Analysis & Prediction</p>
# <section style="text-align:center; ">
# <img src="Heart disease.jpg" style='width: 350px; height: 350px;'>
# </section>
#
# <section style="text-align:justify; ">
# Heart disease is a general term that includes many types of heart problems. It's also called cardiovascular disease, which means heart and blood vessel disease.
# <br/>
# Heart disease is the leading cause of death in the United States, but there are ways to prevent and manage many types of heart disease.
# <br/>
# The causes of heart disease depend on the type of disease. Some possible causes include lifestyle, genetics, infections, medicines, and other diseases.
# the symptoms will depend on the type of heart disease you have. You may not have symptoms at first. In some cases, you may not know you have heart disease until you have a complication such as a heart attack.</section>

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">INDEX</p>
# <ol style="margin-left: 100px;
#     margin-top: 30px;
#     margin-bottom: 20px;
#     margin-right: 10px;">
#     <li>Import libraries</li>
#     <li>Explanation of the variable of the dataset</li>
#     <li>DataFrame</li>
#     <li>Renaming some Attribute</li>
#     <li>Basic Exploration & Summary</li>
#     <li>Checking Datatype</li>
#     <li>Data Preprocessing</li>
#     <li>Data visualization<ul>
#         <li>BMI Distribution</li>
#         <li>Sex Distribution</li>
#         <li>Diabetic Distribution</li>
#         <li>Smoking vs Heart Disease Countplot</li>
#         <li>Alcohol Drinking vs Heart Disease Countplot</li>
#         <li>BMI vs Heart Disease Boxplot</li>
#         <li>Sleep vs Heart Disease Violinplot</li>
#         <li>KDEplot Heart Disease based on physicalhealth</li>
#         <li>KDEplot Heart Disease based on Mentalhealth</li>
#         <li>Feature Correlation Heatmap</li>
#         <li>Distribution of correlation of features</li>
#         <li>Distribution of correlation of features</li>
#     </ul></li>
#     <li>Discription of Final Data</li>
#     <li>Spliting Train & Test Data</li>
#     <li>Modeling</li>
# </ol>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# <<p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Explanation of the variables of the dataset</p>

# %% [markdown]
# **1. HeartDisease:** Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI).</br>
# **2. BMI:** Body Mass Index (BMI).</br>
# **3. Smoking:** Have you smoked at least 100 cigarettes in your entirelife.</br>
# **4. AlcoholDrinking:** Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week.</br>
# **5. Stroke:** (Ever told) (you had) a stroke?</br>
# **6. PhysicalHealth:** Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days was your physical</br>
# **7. MentalHealth:** Thinking about your mental health, for how many days during the past 30 days was your mental health not good?</br>
# **8. DiffWalking:** Do you have serious difficulty walking or climbing stairs?</br>
# **9. Sex:** Are you male or female?</br>
# **10. AgeCategory:** Fourteen-level age category</br>
# **11. Race:** Imputed race/ethnicity value</br>
# **12. Diabetic:** (Ever told) (you had) diabetes?</br>
# **13. PhysicalActivity:** Adults who reported doing physical activity or exercise during the past 30 days other than their regular job</br>
# **14. GenHealth:** Would you say that in general your health is.</br>
# **15. SleepTime:** On average, how many hours of sleep do you get in a 24-hour period?</br>
# **16. Asthma:** (Ever told) (you had) asthma?</br>
# **17. Kidney Disease:** Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?</br>
# **18. SkinCancer:** (Ever told) (you had) skin cancer?

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">DataFrame</p>

# %%
df = pd.read_csv("Heart Disease.csv")
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Renaming some Attrubute</p>

# %%
heart_df = df.rename(columns= {"Race":"Ethnicity","GenHealth":"GeneralHealth","DiffWalking":"DifficultWalking"})
heart_df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DifficultWalking     Sex  AgeCategory Ethnicity Diabetic  \
# 0            30               No  Female        55-59     White      Yes
# 1             0               No  Female  80 or older     White       No
# 2            30               No    Male        65-69     White      Yes
# 3             0               No  Female        75-79     White       No
# 4             0              Yes  Female        40-44     White       No
#
#   PhysicalActivity GeneralHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Basic Exploration & Summary</p>

# %%
heart_df.index
# Out:
# RangeIndex(start=0, stop=319795, step=1)

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DifficultWalking  319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Ethnicity         319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GeneralHealth     319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
heart_df.shape
# Out:
# (319795, 18)

# %%
for col in heart_df.columns:
    print(col)
# Out:
# HeartDisease
# BMI
# Smoking
# AlcoholDrinking
# Stroke
# PhysicalHealth
# MentalHealth
# DifficultWalking
# Sex
# AgeCategory
# Ethnicity
# Diabetic
# PhysicalActivity
# GeneralHealth
# SleepTime
# Asthma
# KidneyDisease
# SkinCancer

# %%
heart_df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DifficultWalking       2
# Sex                    2
# AgeCategory           13
# Ethnicity              6
# Diabetic               4
# PhysicalActivity       2
# GeneralHealth          5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
print("Smoking\n",heart_df["Smoking"].unique())
print("Physical health\n",heart_df["PhysicalHealth"].unique())
print("Mental health\n",heart_df["MentalHealth"].unique())
print("Age Category\n",heart_df["AgeCategory"].unique())
print("Ethnicity\n",heart_df["Ethnicity"].unique())
print("Diabetic\n",heart_df["Diabetic"].unique())
print("GeneralHealth\n",heart_df["GeneralHealth"].unique())
print("Sleep Time\n",heart_df["SleepTime"].unique())
print("Skin Cancer\n",heart_df["SkinCancer"].unique())
# Out:
# Smoking
#  ['Yes' 'No']
# Physical health
#  [ 3  0 20 28  6 15  5 30  7  1  2 21  4 10 14 18  8 25 16 29 27 17 24 12
#  23 26 22 19  9 13 11]
# Mental health
#  [30  0  2  5 15  8  4  3 10 14 20  1  7 24  9 28 16 12  6 25 17 18 21 29
#  22 13 23 27 26 11 19]
# Age Category
#  ['55-59' '80 or older' '65-69' '75-79' '40-44' '70-74' '60-64' '50-54'
#  '45-49' '18-24' '35-39' '30-34' '25-29']
# Ethnicity
#  ['White' 'Black' 'Asian' 'American Indian/Alaskan Native' 'Other'
#  'Hispanic']
# Diabetic
#  ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']
# GeneralHealth
#  ['Very good' 'Fair' 'Good' 'Poor' 'Excellent']
# Sleep Time
#  [ 5  7  8  6 12  4  9 10 15  3  2  1 16 18 14 20 11 13 17 24 19 21 22 23]
# Skin Cancer
#  ['Yes' 'No']

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Checking Datatype</p>

# %%
def detect_mixed_types(column):
    types = column.apply(type).unique()
    return types 
    
mixed_column = {}
for col in df.columns:
    types = detect_mixed_types(df[col])
    mixed_column[col] = types 
print("Columns Type Summary: ")

for col, types in mixed_column.items():
    print(f"Column {col} contains the followig types: {types}")

Column_with_mixed_type = [col for col, types in mixed_column.items() if len(types) >1]
print("\nColumns with mixed data types:", Column_with_mixed_type)
# Out:
# Columns Type Summary:
# Column HeartDisease contains the followig types: [<class 'str'>]
# Column BMI contains the followig types: [<class 'float'>]
# Column Smoking contains the followig types: [<class 'str'>]
# Column AlcoholDrinking contains the followig types: [<class 'str'>]
# Column Stroke contains the followig types: [<class 'str'>]
# Column PhysicalHealth contains the followig types: [<class 'int'>]
# Column MentalHealth contains the followig types: [<class 'int'>]
# Column DiffWalking contains the followig types: [<class 'str'>]
# Column Sex contains the followig types: [<class 'str'>]
# Column AgeCategory contains the followig types: [<class 'str'>]
# Column Race contains the followig types: [<class 'str'>]
# Column Diabetic contains the followig types: [<class 'str'>]
# Column PhysicalActivity contains the followig types: [<class 'str'>]
# Column GenHealth contains the followig types: [<class 'str'>]
# Column SleepTime contains the followig types: [<class 'int'>]
# ...

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Data Preprocessing</p>

# %%
encoding = LabelEncoder()
heart_df["Smoking"] = encoding.fit_transform(heart_df["Smoking"])
heart_df["AlcoholDrinking"] =encoding.fit_transform(heart_df["AlcoholDrinking"])
heart_df["Stroke"] =encoding.fit_transform(heart_df["Stroke"])
heart_df["HeartDisease"] =encoding.fit_transform(heart_df["HeartDisease"])
heart_df["DifficultWalking"] =encoding.fit_transform(heart_df["DifficultWalking"])
heart_df["Sex"] =encoding.fit_transform(heart_df["Sex"])
heart_df["Ethnicity"] =encoding.fit_transform(heart_df["Ethnicity"])
heart_df["Diabetic"] =encoding.fit_transform(heart_df["Diabetic"])
heart_df["PhysicalActivity"] =encoding.fit_transform(heart_df["PhysicalActivity"])
heart_df["GeneralHealth"] =encoding.fit_transform(heart_df["GeneralHealth"])
heart_df["Asthma"] =encoding.fit_transform(heart_df["Asthma"])
heart_df["KidneyDisease"] =encoding.fit_transform(heart_df["KidneyDisease"])
heart_df["Asthma"] =encoding.fit_transform(heart_df["Asthma"])
heart_df["SkinCancer"] =encoding.fit_transform(heart_df["SkinCancer"])

# %%
heart_df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DifficultWalking  Sex  AgeCategory  Ethnicity  Diabetic  \
# 0            30                 0    0        55-59          5         2
# 1             0                 0    0  80 or older          5         0
# 2            30                 0    1        65-69          5         2
# 3             0                 0    0        75-79          5         0
# 4             0                 1    0        40-44          5         0
#
#    PhysicalActivity  GeneralHealth  SleepTime  Asthma  KidneyDisease  \
# ...

# %%
heart_df.isnull().values.any()
# Out:
# False

# %%
def calculate_midpoint(AgeCategory):
    if " or older" in AgeCategory:
        lower = int(AgeCategory.split()[0])
        higher = 100
        return (lower+higher) / 2
    else:
        lower, higher = map(int, AgeCategory.split("-"))
        return (lower+higher)/2

# %%
heart_df["Age"] = heart_df["AgeCategory"].apply(calculate_midpoint)
final_data = heart_df.drop(columns="AgeCategory")
final_data
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319793             0  32.81        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
# ...

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">**Data visualization**</p>

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">BMI Distribution</p>

# %%
plt.title("BMI Distribution")
sns.histplot(df, x= "BMI",kde=True, bins= 50, hue= "HeartDisease")
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Sex Distribution</p>

# %%
sns.countplot(data=df, x='Sex', hue ="HeartDisease" )
plt.title('Sex Distribution')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Diabetic Distribution</p>

# %%
sns.countplot(data=df, x='Diabetic', hue ="HeartDisease" )
plt.title('Diabetic Distribution')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Smoking vs Heart Disease Countplot</p>

# %%
sns.countplot(data=df, x='Smoking', hue='HeartDisease')
plt.title('Smoking vs Heart Disease')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Alcohol Drinking vs Heart Disease Countplot</p>

# %%
sns.countplot(data=df, x='AlcoholDrinking', hue='HeartDisease')
plt.title('Alcohol Drinking vs Heart Disease')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">BMI vs Heart Disease Boxplot</p>

# %%
sns.boxplot(data=df, x='HeartDisease', y='BMI')
plt.title('BMI vs Heart Disease')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Sleep vs Heart Disease Violinplot</p>

# %%
sns.violinplot(data=df, x='HeartDisease', y='SleepTime')
plt.title('SleepTime vs Heart Disease')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">KDEplot Heart Disease based on physicalhealth</p>

# %%
sns.kdeplot(final_data, x="PhysicalHealth", hue="HeartDisease", fill=True, bw_adjust=1)
plt.title("Distribution of PhysicalHealth")
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">KDEplot Heart Disease based on Mentalhealth</p>

# %%
sns.kdeplot(final_data, x="MentalHealth", hue="HeartDisease", fill=True,palette="husl")
plt.title("Distribution of MentalHealth")
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Feature Correlation Heatmao</p>

# %%
plt.figure(figsize=(16,16))
corr = final_data.corr().round(2)
sns.heatmap(corr, annot=True,cmap='viridis')
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Distribution of correlation of feature</p>

# %%
sns.set_palette('Set2')
plt.figure(figsize = (13,6))
plt.title('Distribution of correlation of features')
abs(corr['HeartDisease']).sort_values()[:-1].plot.barh()
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Distribution of correlation of features</p>

# %%
sns.pairplot(df, vars=['BMI', 'SleepTime', 'PhysicalHealth'], hue='HeartDisease')
plt.show()

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Discription of Final Data</p>

# %%
final_data.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DifficultWalking  Sex  Ethnicity  Diabetic  PhysicalActivity  \
# 0            30                 0    0          5         2                 1
# 1             0                 0    0          5         0                 1
# 2            30                 0    1          5         2                 1
# 3             0                 0    0          5         0                 0
# 4             0                 1    0          5         0                 1
#
# ...

# %%
final_data.describe()
# Out:
#         HeartDisease            BMI        Smoking  AlcoholDrinking  \
# count  319795.000000  319795.000000  319795.000000    319795.000000
# mean        0.085595      28.325399       0.412477         0.068097
# std         0.279766       6.356100       0.492281         0.251912
# min         0.000000      12.020000       0.000000         0.000000
# 25%         0.000000      24.030000       0.000000         0.000000
# 50%         0.000000      27.340000       0.000000         0.000000
# 75%         0.000000      31.420000       1.000000         0.000000
# max         1.000000      94.850000       1.000000         1.000000
#
#               Stroke  PhysicalHealth   MentalHealth  DifficultWalking  \
# count  319795.000000    319795.00000  319795.000000     319795.000000
# mean        0.037740         3.37171       3.898366          0.138870
# std         0.190567         7.95085       7.955235          0.345812
# min         0.000000         0.00000       0.000000          0.000000
# ...

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Spliting Train & Test Data</p>

# %%
x = final_data.drop("HeartDisease", axis= 1)
y = final_data["HeartDisease"]
xtrain, xtest, ytrain, ytest = train_test_split(x, y,test_size=0.25, random_state=50)
print("Shape of Train feature data: ", xtrain.shape)
print("Shape of test feature data: ", xtest.shape)
print("Shape of Train target data: ",ytrain.shape)
print("Shape of test target data: ", ytest.shape)
# Out:
# Shape of Train feature data:  (239846, 17)
# Shape of test feature data:  (79949, 17)
# Shape of Train target data:  (239846,)
# Shape of test target data:  (79949,)

# %%
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.fit_transform(xtest)

# %% [markdown]
# <p style="padding:10px;background-color:#432C0A;margin:0;color:#33caff;font-family:newtimeroman;font-size:150%;
# text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Modeling</p>

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(xtrain,ytrain)
prediction = knn.predict(xtest)
print("Accuracy: ", metrics.accuracy_score(ytest, prediction))
print("Recall Score: ", metrics.recall_score(ytest, prediction))
print("Precision Score: ", metrics.precision_score(ytest, prediction))
print("Confution Metrix", metrics.confusion_matrix(ytest, prediction))
# Out:
# Accuracy:  0.9049519068406109
# Recall Score:  0.12439701797982751
# Precision Score:  0.3459349593495935
# Confution Metrix [[71499  1609]
#  [ 5990   851]]

# %%
decisiontree = DecisionTreeClassifier()
decisiontree.fit(xtrain,ytrain)
prediction_tree = decisiontree.predict(xtest)
print("Accuracy: ",metrics.accuracy_score(ytest,prediction_tree))
print("Recall Score: ",metrics.recall_score(ytest,prediction_tree))
print("Precision Score: ", metrics.precision_score(ytest,prediction_tree))
print("Confusion Metrix: ", metrics.confusion_matrix(ytest,prediction_tree))
# Out:
# Accuracy:  0.8638131809028256
# Recall Score:  0.25200994006724164
# Precision Score:  0.23002001334222816
# Confusion Metrix:  [[67337  5771]
#  [ 5117  1724]]
